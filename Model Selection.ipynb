# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
dataset=pd.read_csv("reduced_dataset.csv")

# %%
dataset
# Out:
#      make  model  year  mileage  engine_hp  transmission  fuel_type  \
# 0      19      1  2018    94000        181             0          1
# 1      18     68  2021    94190        464             1          1
# 2       1      7  2020    76853        325             1          0
# 3      19      0  2017   109290        223             1          2
# 4       7     39  2019    40701        212             0          2
# ..    ...    ...   ...      ...        ...           ...        ...
# 995     8      9  2021    65349        170             0          2
# 996    16     80  2009   220415        322             0          1
# 997    13     78  2020   135697        400             1          1
# 998    12     92  2014   191197         97             1          2
# 999    13     29  2024    16362        425             1          1
#
#      drivetrain  body_type  exterior_color  interior_color  owner_count  \
# 0             0          3               2               3            5
# 1             1          5               0               3            2
# 2             0          5               3               2            1
# 3             2          3               4               0            5
# 4             0          4               4               3            3
# ..          ...        ...             ...             ...          ...
# 995           2          4               0               2            1
# 996           0          5               5               2            5
# 997           2          4               4               1            4
# 998           0          5               4               0            5
# 999           0          4               3               2            2
#
#      accident_history  seller_type  condition  trim  vehicle_age  \
# 0                   2            0          2     1            7
# 1                   2            0          0     5            4
# 2                   2            1          1     5            5
# 3                   2            0          2     5            8
# 4                   2            1          2     2            6
# ..                ...          ...        ...   ...          ...
# 995                 2            0          0     5            4
# 996                 0            0          2     0           16
# 997                 1            0          2     0            5
# 998                 2            1          2     3           11
# 999                 2            0          2     2            1
#
#      mileage_per_year  brand_popularity     price
# 0        13428.571429          0.040148  19226.82
# 1        23547.500000          0.040210  60435.02
# 2        15370.600000          0.040022  28708.28
# 3        13661.250000          0.040148  18938.64
# 4         6783.500000          0.039842  18487.37
# ..                ...               ...       ...
# 995      16337.250000          0.039754  27227.54
# 996      13775.937500          0.039794   7112.87
# 997      27139.400000          0.040133  41265.44
# 998      17381.545455          0.040484   1500.00
# 999      16362.000000          0.040133  70796.08
#
# [1000 rows x 20 columns]

# %%
dataset.columns
# Out:
# Index(['make', 'model', 'year', 'mileage', 'engine_hp', 'transmission',
#        'fuel_type', 'drivetrain', 'body_type', 'exterior_color',
#        'interior_color', 'owner_count', 'accident_history', 'seller_type',
#        'condition', 'trim', 'vehicle_age', 'mileage_per_year',
#        'brand_popularity', 'price'],
#       dtype='object')

# %%
independent=dataset[['make', 'model', 'year', 'mileage', 'engine_hp', 'transmission',
       'fuel_type', 'drivetrain', 'body_type', 'exterior_color',
       'interior_color', 'owner_count', 'accident_history', 'seller_type',
       'condition', 'trim', 'vehicle_age', 'mileage_per_year',
       'brand_popularity']]

# %%
dependent=dataset[['price']]

# %%
#Random Forest
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=1/3,random_state=0)
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(n_estimators=100, criterion ='poisson', random_state=0)
regressor.fit(X_train,y_train)
y_predict=regressor.predict(X_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_predict)
print(r_score)
# Out:
# 0.937597169397364

# %%
import pickle
filename="model_rf.sav"
pickle.dump(y_predict,open(filename,'wb'))

# %%
dataset
# Out:
#      make  model  year  mileage  engine_hp  transmission  fuel_type  \
# 0      19      1  2018    94000        181             0          1
# 1      18     68  2021    94190        464             1          1
# 2       1      7  2020    76853        325             1          0
# 3      19      0  2017   109290        223             1          2
# 4       7     39  2019    40701        212             0          2
# ..    ...    ...   ...      ...        ...           ...        ...
# 995     8      9  2021    65349        170             0          2
# 996    16     80  2009   220415        322             0          1
# 997    13     78  2020   135697        400             1          1
# 998    12     92  2014   191197         97             1          2
# 999    13     29  2024    16362        425             1          1
#
#      drivetrain  body_type  exterior_color  interior_color  owner_count  \
# 0             0          3               2               3            5
# 1             1          5               0               3            2
# 2             0          5               3               2            1
# 3             2          3               4               0            5
# 4             0          4               4               3            3
# ..          ...        ...             ...             ...          ...
# 995           2          4               0               2            1
# 996           0          5               5               2            5
# 997           2          4               4               1            4
# 998           0          5               4               0            5
# 999           0          4               3               2            2
#
#      accident_history  seller_type  condition  trim  vehicle_age  \
# 0                   2            0          2     1            7
# 1                   2            0          0     5            4
# 2                   2            1          1     5            5
# 3                   2            0          2     5            8
# 4                   2            1          2     2            6
# ..                ...          ...        ...   ...          ...
# 995                 2            0          0     5            4
# 996                 0            0          2     0           16
# 997                 1            0          2     0            5
# 998                 2            1          2     3           11
# 999                 2            0          2     2            1
#
#      mileage_per_year  brand_popularity     price
# 0        13428.571429          0.040148  19226.82
# 1        23547.500000          0.040210  60435.02
# 2        15370.600000          0.040022  28708.28
# 3        13661.250000          0.040148  18938.64
# 4         6783.500000          0.039842  18487.37
# ..                ...               ...       ...
# 995      16337.250000          0.039754  27227.54
# 996      13775.937500          0.039794   7112.87
# 997      27139.400000          0.040133  41265.44
# 998      17381.545455          0.040484   1500.00
# 999      16362.000000          0.040133  70796.08
#
# [1000 rows x 20 columns]

# %%
# Save the trained model
filename = "model_rf.sav"
pickle.dump(regressor, open(filename, 'wb'))

# Load the model
loaded_model = pickle.load(open("model_rf.sav", 'rb'))

# Use the loaded model for prediction
result = loaded_model.predict([[13,29,2024,16362,425,1,1,0,4,3,2,2,2,0,2,2,1,16362.00,0.040133]])
print("Prediction:", result)
# Out:
# Prediction: [59400.0002]
